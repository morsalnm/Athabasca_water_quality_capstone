# %%
import pandas as pd

kearl = pd.read_csv('KearlLake_Data.csv')
gregoire = pd.read_csv('gregoireLake_Data.csv')

# %%
gregoire
# Out:
#     sampling_timestamp  Aluminum Dissolved  Aluminum Total Recoverable  \
# 0  2014-05-08 12:00:00                 NaN                         NaN
# 1  2014-07-10 12:00:00               20.10                      1540.0
# 2  2014-09-07 12:00:00               19.40                      3500.0
# 3  2015-03-02 12:00:00                4.79                       259.0
# 4  2016-03-10 12:00:00                2.85                       239.0
# 5  2016-07-20 12:00:00               40.00                       519.0
# 6  2016-09-21 12:00:00               25.40                       534.0
# 7  2017-03-15 12:00:00                8.91                        96.2
#
#    Calcium Dissolved  Calcium Total  Copper Dissolved  \
# 0            23900.0            NaN               NaN
# 1            26400.0        21900.0              0.82
# 2            39700.0        33800.0              0.73
# 3            33000.0        31000.0              0.45
# ...

# %%
df = pd.concat([kearl, gregoire])

# %%
df
# Out:
#      sampling_timestamp  Aluminum Dissolved  Aluminum Total Recoverable  \
# 0   2000-09-27 12:00:00                 NaN                         NaN
# 1   2001-09-13 12:00:00                 NaN                         NaN
# 2   2002-09-04 12:00:00                 NaN                         NaN
# 3   2003-03-24 12:00:00               6.000                       19.40
# 4   2003-08-31 12:00:00                 NaN                         NaN
# 5   2004-06-17 14:30:00                 NaN                         NaN
# 6   2004-07-14 09:15:00                 NaN                         NaN
# 7   2004-07-26 12:00:00               2.120                       17.80
# 8   2004-08-24 15:05:00               0.940                       12.70
# 9   2004-09-25 13:10:00                 NaN                         NaN
# 10  2005-04-07 08:00:00                 NaN                         NaN
# 11  2005-05-26 12:00:00                 NaN                         NaN
# ...

# %%
df["sampling_timestamp"] = pd.to_datetime(
    df["sampling_timestamp"], errors="coerce"
)
df = df.sort_values(by="sampling_timestamp")
df["Distance Group"] = "Near-Fields"

df
# Out:
#     sampling_timestamp  Aluminum Dissolved  Aluminum Total Recoverable  \
# 0  2000-09-27 12:00:00                 NaN                         NaN
# 1  2001-09-13 12:00:00                 NaN                         NaN
# 2  2002-09-04 12:00:00                 NaN                         NaN
# 3  2003-03-24 12:00:00               6.000                       19.40
# 4  2003-08-31 12:00:00                 NaN                         NaN
# 5  2004-06-17 14:30:00                 NaN                         NaN
# 6  2004-07-14 09:15:00                 NaN                         NaN
# 7  2004-07-26 12:00:00               2.120                       17.80
# 8  2004-08-24 15:05:00               0.940                       12.70
# 9  2004-09-25 13:10:00                 NaN                         NaN
# 10 2005-04-07 08:00:00                 NaN                         NaN
# 11 2005-05-26 12:00:00                 NaN                         NaN
# ...

# %%
df.describe()
# Out:
#                   sampling_timestamp  Aluminum Dissolved  \
# count                             51           37.000000
# mean   2010-12-04 04:21:10.588235264            5.047351
# min              2000-09-27 12:00:00            0.514000
# 25%              2005-07-18 00:00:00            1.060000
# 50%              2011-09-01 08:30:00            1.430000
# 75%              2015-12-04 09:45:00            2.850000
# max              2022-09-16 07:20:00           40.000000
# std                              NaN            8.452028
#
#        Aluminum Total Recoverable  Calcium Dissolved  Calcium Total  \
# count                   39.000000          51.000000      37.000000
# mean                   184.781026       22951.960784   23727.027027
# min                      3.700000       12400.000000   15200.000000
# 25%                     10.650000       17600.000000   18500.000000
# 50%                     17.000000       20300.000000   20100.000000
# ...

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(20,16))
plt.show()

# %%
import matplotlib.pyplot as plt

chem_cols = [
    "Aluminum Dissolved",
    "Aluminum Total Recoverable",
    "Calcium Dissolved",
    "Calcium Total",
    "Copper Dissolved",
    "Copper Total Recoverable",
    "Lead Dissolved",
    "Lead Total Recoverable",
    "Nickel Dissolved",
    "Nickel Total Recoverable",
    "Nitrogen Dissolved",
    "Phosphorus Total Dissolved",
    "Phosphorus Total",
    "Vanadium Dissolved",
    "Turbidity",
    "pH",
    "Oxygen dissolved % saturation"
]

fig, axes = plt.subplots(5, 4, figsize=(25,15))
axes = axes.flatten()

for i, col in enumerate(chem_cols):
    axes[i].boxplot(df[col].dropna())
    axes[i].set_title(col)
    axes[i].set_ylabel("Concentration")

plt.tight_layout()
plt.show()

# %%
import matplotlib.dates as mdates

fig, axes = plt.subplots(5, 4, figsize=(25,15))
axes = axes.flatten()

for i, col in enumerate(chem_cols):
    ax = axes[i]
    
    for lake in df["Site Name"].unique():
        lake_data = df[df["Site Name"] == lake]
        
        ax.scatter(
            lake_data["sampling_timestamp"],
            lake_data[col],
            label=lake
            
        )
       

    ax.xaxis.set_major_locator(mdates.AutoDateLocator(minticks=5))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    ax.tick_params(axis='x', rotation=45)
    
    ax.set_title(col)
    ax.set_xlabel("Date")
    ax.set_ylabel("Concentration")

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc="upper right")

plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 42
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   sampling_timestamp             51 non-null     datetime64[ns]
#  1   Aluminum Dissolved             37 non-null     float64
#  2   Aluminum Total Recoverable     39 non-null     float64
#  3   Calcium Dissolved              51 non-null     float64
#  4   Calcium Total                  37 non-null     float64
#  5   Copper Dissolved               37 non-null     float64
#  6   Copper Total Recoverable       39 non-null     float64
#  7   Lead Dissolved                 37 non-null     float64
#  8   Lead Total Recoverable         39 non-null     float64
#  9   Nickel Dissolved               37 non-null     float64
#  10  Nickel Total Recoverable       39 non-null     float64
#  11  Nitrogen Dissolved             21 non-null     float64
# ...

# %%
df.to_csv("NearLake_Data.csv", index= False)
